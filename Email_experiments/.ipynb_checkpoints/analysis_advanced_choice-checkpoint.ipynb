# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import statsmodels.formula.api as smf
from input.plot_styles import family_colors, set_plot_style, model_order

# %%
set_plot_style()

# %%
model_dict = {"qwen8":"Qwen/Qwen3-8B",
             "qwen14": "Qwen/Qwen3-14B",
             "gemma12": "google/gemma-3-12b-it",
             "gemma27": "google/gemma-3-27b-it",
             "llama8": "meta-llama/Llama-3.1-8B-Instruct",
             "ministral14": "mistralai/Ministral-3-14B-Instruct-2512",
             "ministral8": "mistralai/Ministral-3-8B-Instruct-2512"}

# %% [markdown]
# ### Loading Data

# %%
def load_results_to_dict(num_mails, subfolder = "both"):
    
    directory = f"results/results_advanced_choice/{num_mails}/{subfolder}"
    
    df_dict = {}
    
    # Check if directory exists
    if not os.path.exists(directory):
        print(f"Directory {directory} not found.")
        return df_dict

    # Iterate through files in the folder
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            # Extract model name from filename (e.g., 'answers_choose5_llama8.csv')
            # split by '_' and use the last part without '.csv'
            model_name = filename.split('_')[-1].replace('.csv', '')
            
            # Load the dataframe
            file_path = os.path.join(directory, filename)
            df_dict[model_name] = pd.read_csv(file_path)
            
            print(f"✓ Loaded {model_name}")
            
    return df_dict

# %%
# Loading for not urgent with control
df_dict_2_control = load_results_to_dict(2,"not_urgent")
df_dict_5_control = load_results_to_dict(5, "not_urgent")
df_dict_10_control = load_results_to_dict(10, "not_urgent")
# Out:
# ✓ Loaded gemma12
# ✓ Loaded gemma27
# ✓ Loaded llama8
# ✓ Loaded ministral14
# ✓ Loaded ministral8
# ✓ Loaded qwen8
# ✓ Loaded qwen14
# ✓ Loaded gemma12
# ✓ Loaded llama8
# ✓ Loaded gemma27
# ✓ Loaded ministral14
# ✓ Loaded ministral8
# ✓ Loaded qwen14
# ✓ Loaded qwen8
# ✓ Loaded gemma12
# ✓ Loaded llama8
# ✓ Loaded ministral8
# ✓ Loaded ministral14
# ✓ Loaded gemma27
# ✓ Loaded qwen8
# ✓ Loaded qwen14

# %%
# Loading for not urgent with control
df_dict_2_control_urgent = load_results_to_dict(2,"urgent")
df_dict_5_control_urgent = load_results_to_dict(5, "urgent")
df_dict_10_control_urgent = load_results_to_dict(10, "urgent")
# Out:
# ✓ Loaded gemma12
# ✓ Loaded gemma27
# ✓ Loaded llama8
# ✓ Loaded ministral14
# ✓ Loaded ministral8
# ✓ Loaded qwen8
# ✓ Loaded qwen14
# ✓ Loaded gemma12
# ✓ Loaded gemma27
# ✓ Loaded ministral14
# ✓ Loaded llama8
# ✓ Loaded ministral8
# ✓ Loaded qwen8
# ✓ Loaded qwen14
# ✓ Loaded gemma12
# ✓ Loaded gemma27
# ✓ Loaded ministral14
# ✓ Loaded ministral8
# ✓ Loaded llama8
# ✓ Loaded qwen8
# ✓ Loaded qwen14

# %%
# Loading for all randomized
df_dict_2 = load_results_to_dict(2)
df_dict_5 = load_results_to_dict(5)
df_dict_10 = load_results_to_dict(10)
# Out:
# ✓ Loaded gemma12
# ✓ Loaded gemma27
# ✓ Loaded llama8
# ✓ Loaded ministral8
# ✓ Loaded ministral14
# ✓ Loaded qwen8
# ✓ Loaded qwen14
# ✓ Loaded llama8
# ✓ Loaded gemma12
# ✓ Loaded ministral14
# ✓ Loaded gemma27
# ✓ Loaded ministral8
# ✓ Loaded qwen8
# ✓ Loaded qwen14
# ✓ Loaded gemma12
# ✓ Loaded qwen8
# ✓ Loaded qwen14
# ✓ Loaded llama8
# ✓ Loaded gemma27
# ✓ Loaded ministral14
# ✓ Loaded ministral8

# %% [markdown]
# ### Plotting the data

# %%
dicts = {2: {"not urgent": df_dict_2_control, "urgent": df_dict_2_control_urgent}, 
         5: {"not urgent": df_dict_5_control, "urgent": df_dict_5_control_urgent},
         10: {"not urgent": df_dict_10_control, "urgent": df_dict_10_control_urgent}}

# %%
def plot_onecond(df_dict, num_mails, color_map, urgent):
    plt.figure(figsize=(3.2, 3.5*0.7))
    processed_dfs = {}

    for model_name, df in df_dict.items():
        
     # Calculate means per bystander difference
        means = df.groupby("delta_b")["delta_prob"].mean()
        # Standard Error (SE) = Standard Deviation / sqrt(n)
        se = df.groupby("delta_b")["delta_prob"].sem()

        line_color = family_colors.get(model_name, "gray")
        
        # Use errorbar 
        plt.errorbar(means.index.astype(int), 
                     means, 
                     yerr=se,          
                     marker='o', 
                     ms=3,
                     linestyle='-', 
                     label=model_name, 
                     color=line_color, 
                     linewidth=1.5,
                     capsize=3,
                     capthick =1,
                     alpha = 0.8
                    )            
            
        
    # Plot Styling
    if num_mails == 10:
        plt.xlabel(r"$\Delta$ recipients", fontsize=10, labelpad = 8)
    plt.xticks(np.arange(0, 21, 2), fontsize = 10)

    if urgent == "not urgent":
        plt.ylabel(r"$\Delta$ probabilities", fontsize= 10, labelpad = 8)
    else:
        plt.ylabel(r" * ", fontsize= 10, labelpad = 8, c = "white")
    plt.yticks(fontsize = 10)
    plt.ylim(-1.1,0.7) 
    plt.axhline(y= 0, color='r', linestyle='--', linewidth=1)
    plt.grid(True, linestyle='--', alpha=0.5)
    
    plt.tight_layout()
    plt.savefig(f"plots/advanced_choice/overview_{num_mails}_{urgent}_a.pdf")
    plt.show()

# %%
for n_mails, df_dict_u in dicts.items():
    
    for urgent, df_dict in df_dict_u.items():

        plot_onecond(df_dict, n_mails, family_colors, urgent)

# %% [markdown]
# ### Statistical Analysis

# %%
def estimate_beta(df):
    # 1. Preprocessing
    df["log_byst"] = np.log(df["bystander"])
    
    # 2. Model Specification & Fitting
    formula = "prob ~ log_byst * urgency + pos"
    
    result = smf.ols(formula, df).fit(cov_type='cluster', 
                                      cov_kwds={'groups': df['trial']})
    print(result.summary())
    
    # 3. Extracting Parameters
    beta_b = result.params["log_byst"]
    se_b = result.bse["log_byst"]
    
    beta_int = result.params["log_byst:urgency"]
    se_int = result.bse["log_byst:urgency"]
    
    return beta_b, se_b, beta_int, se_int

# %%
def compare_model_coef(df_dict):
    
    rows = []
    
    for model_name, df in df_dict.items():
        print("------", model_name)
        beta_b, se_b, beta_int, se_int = estimate_beta(df)
        rows.append({
            "model": model_name,
            "beta byst": beta_b,
            "se byst": se_b,
            "ci_low byst": beta_b - 1.96 * se_b,
            "ci_high byst": beta_b + 1.96 * se_b,
            "beta int": beta_int,
            "se int": se_int,
            "ci_low int": beta_int - 1.96 * se_int,
            "ci_high int": beta_int + 1.96 * se_int
        })

    summary = pd.DataFrame(rows)

    # sort by defined model order
    summary["model"] = pd.Categorical(
        summary["model"], categories=model_order, ordered=True
    )
    summary = summary.sort_values("model")
    
    return summary

# %%
df_summary_2 = compare_model_coef(df_dict_2)
# Out:
# ------ gemma12
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.261
# Model:                            OLS   Adj. R-squared:                  0.261
# Method:                 Least Squares   F-statistic:                     1554.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:19   Log-Likelihood:                -5338.7
# No. Observations:               10000   AIC:                         1.069e+04
# Df Residuals:                    9995   BIC:                         1.072e+04
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.3497      0.007     51.381      0.000       0.336       0.363
# log_byst            -0.1492      0.005    -31.653      0.000      -0.158      -0.140
# urgency              0.3919      0.010     41.043      0.000       0.373       0.411
# log_byst:urgency     0.0162      0.011      1.481      0.139      -0.005       0.038
# pos                  0.2230      0.011     20.567      0.000       0.202       0.244
# ==============================================================================
# Omnibus:                     3091.161   Durbin-Watson:                   2.737
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              464.916
# Skew:                           0.034   Prob(JB):                    1.11e-101
# Kurtosis:                       1.946   Cond. No.                         4.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# ------ gemma27
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.234
# Model:                            OLS   Adj. R-squared:                  0.234
# Method:                 Least Squares   F-statistic:                     1377.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:19   Log-Likelihood:                -5794.3
# No. Observations:               10000   AIC:                         1.160e+04
# Df Residuals:                    9995   BIC:                         1.163e+04
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.5697      0.008     72.598      0.000       0.554       0.585
# log_byst            -0.1309      0.005    -23.951      0.000      -0.142      -0.120
# urgency              0.3969      0.010     40.745      0.000       0.378       0.416
# log_byst:urgency    -0.0257      0.011     -2.238      0.025      -0.048      -0.003
# pos                 -0.2257      0.011    -19.657      0.000      -0.248      -0.203
# ==============================================================================
# Omnibus:                     6689.385   Durbin-Watson:                   2.745
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              577.989
# Skew:                           0.072   Prob(JB):                    3.10e-126
# Kurtosis:                       1.831   Cond. No.                         4.79
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# ------ llama8
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.504
# Model:                            OLS   Adj. R-squared:                  0.504
# Method:                 Least Squares   F-statistic:                     4074.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:19   Log-Likelihood:                -428.89
# No. Observations:               10000   AIC:                             867.8
# Df Residuals:                    9995   BIC:                             903.8
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.6926      0.005    140.749      0.000       0.683       0.702
# log_byst            -0.1205      0.004    -33.360      0.000      -0.128      -0.113
# urgency              0.2599      0.007     35.451      0.000       0.245       0.274
# log_byst:urgency    -0.0367      0.006     -5.708      0.000      -0.049      -0.024
# pos                 -0.4026      0.006    -62.416      0.000      -0.415      -0.390
# ==============================================================================
# Omnibus:                       22.610   Durbin-Watson:                   2.602
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.748
# Skew:                          -0.115   Prob(JB):                     1.15e-05
# Kurtosis:                       2.956   Cond. No.                         4.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# ------ ministral8
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.416
# Model:                            OLS   Adj. R-squared:                  0.416
# Method:                 Least Squares   F-statistic:                     1992.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:19   Log-Likelihood:                 586.48
# No. Observations:               10000   AIC:                            -1163.
# Df Residuals:                    9995   BIC:                            -1127.
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.5550      0.005    118.390      0.000       0.546       0.564
# log_byst             0.0126      0.003      3.602      0.000       0.006       0.019
# urgency              0.2887      0.007     41.062      0.000       0.275       0.302
# log_byst:urgency    -0.0240      0.007     -3.488      0.000      -0.038      -0.011
# pos                 -0.2874      0.006    -48.126      0.000      -0.299      -0.276
# ==============================================================================
# Omnibus:                      309.924   Durbin-Watson:                   2.683
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              217.364
# Skew:                          -0.254   Prob(JB):                     6.31e-48
# Kurtosis:                       2.486   Cond. No.                         4.83
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# ------ ministral14
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.372
# Model:                            OLS   Adj. R-squared:                  0.372
# Method:                 Least Squares   F-statistic:                     1849.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:19   Log-Likelihood:                -1149.6
# No. Observations:               10000   AIC:                             2309.
# Df Residuals:                    9995   BIC:                             2345.
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.4920      0.006     88.568      0.000       0.481       0.503
# log_byst            -0.0313      0.004     -8.383      0.000      -0.039      -0.024
# urgency              0.4175      0.008     52.944      0.000       0.402       0.433
# log_byst:urgency    -0.0355      0.007     -4.827      0.000      -0.050      -0.021
# pos                 -0.1900      0.007    -28.297      0.000      -0.203      -0.177
# ==============================================================================
# Omnibus:                      476.199   Durbin-Watson:                   2.532
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              252.802
# Skew:                          -0.221   Prob(JB):                     1.27e-55
# Kurtosis:                       2.358   Cond. No.                         4.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# ------ qwen8
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.249
# Model:                            OLS   Adj. R-squared:                  0.249
# Method:                 Least Squares   F-statistic:                     1124.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:19   Log-Likelihood:                -4636.8
# No. Observations:               10000   AIC:                             9284.
# Df Residuals:                    9995   BIC:                             9320.
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.3136      0.006     52.227      0.000       0.302       0.325
# log_byst            -0.0701      0.005    -13.562      0.000      -0.080      -0.060
# urgency              0.4168      0.009     45.229      0.000       0.399       0.435
# log_byst:urgency     0.0018      0.010      0.180      0.857      -0.018       0.022
# pos                  0.1984      0.010     19.637      0.000       0.179       0.218
# ==============================================================================
# Omnibus:                     1975.828   Durbin-Watson:                   2.731
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              395.224
# Skew:                           0.025   Prob(JB):                     1.51e-86
# Kurtosis:                       2.027   Cond. No.                         4.85
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# ------ qwen14
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.262
# Model:                            OLS   Adj. R-squared:                  0.262
# Method:                 Least Squares   F-statistic:                     1169.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:19   Log-Likelihood:                -5490.5
# No. Observations:               10000   AIC:                         1.099e+04
# Df Residuals:                    9995   BIC:                         1.103e+04
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.5400      0.008     65.522      0.000       0.524       0.556
# log_byst            -0.0621      0.007     -9.443      0.000      -0.075      -0.049
# urgency              0.4206      0.010     40.607      0.000       0.400       0.441
# log_byst:urgency     0.0496      0.012      4.100      0.000       0.026       0.073
# pos                 -0.2787      0.011    -25.241      0.000      -0.300      -0.257
# ==============================================================================
# Omnibus:                     1301.915   Durbin-Watson:                   2.745
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              329.962
# Skew:                           0.008   Prob(JB):                     2.24e-72
# Kurtosis:                       2.110   Cond. No.                         4.85
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)

# %%
df_summary_5 = compare_model_coef(df_dict_5)
# Out:
# ------ llama8
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.368
# Model:                            OLS   Adj. R-squared:                  0.368
# Method:                 Least Squares   F-statistic:                     3380.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:20   Log-Likelihood:                 7133.0
# No. Observations:               25000   AIC:                        -1.426e+04
# Df Residuals:                   24995   BIC:                        -1.422e+04
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.1003      0.002     45.284      0.000       0.096       0.105
# log_byst            -0.0477      0.001    -50.269      0.000      -0.050      -0.046
# urgency              0.2986      0.004     67.545      0.000       0.290       0.307
# log_byst:urgency    -0.0973      0.003    -31.375      0.000      -0.103      -0.091
# pos                  0.0260      0.001     30.307      0.000       0.024       0.028
# ==============================================================================
# Omnibus:                     3294.062   Durbin-Watson:                   2.149
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5497.642
# Skew:                           0.900   Prob(JB):                         0.00
# Kurtosis:                       4.428   Cond. No.                         9.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# ------ gemma12
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.281
# Model:                            OLS   Adj. R-squared:                  0.281
# Method:                 Least Squares   F-statistic:                     3599.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:20   Log-Likelihood:                -7980.8
# No. Observations:               25000   AIC:                         1.597e+04
# Df Residuals:                   24995   BIC:                         1.601e+04
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.0886      0.004     22.157      0.000       0.081       0.096
# log_byst            -0.0401      0.001    -28.356      0.000      -0.043      -0.037
# urgency              0.4658      0.006     75.564      0.000       0.454       0.478
# log_byst:urgency    -0.0545      0.007     -8.134      0.000      -0.068      -0.041
# pos                 -0.0006      0.002     -0.399      0.690      -0.004       0.002
# ==============================================================================
# Omnibus:                     2637.978   Durbin-Watson:                   2.248
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3697.750
# Skew:                           0.835   Prob(JB):                         0.00
# Kurtosis:                       3.871   Cond. No.                         9.13
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# ------ ministral14
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.447
# Model:                            OLS   Adj. R-squared:                  0.447
# Method:                 Least Squares   F-statistic:                     3130.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:20   Log-Likelihood:                 3732.3
# No. Observations:               25000   AIC:                            -7455.
# Df Residuals:                   24995   BIC:                            -7414.
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.0327      0.002     14.036      0.000       0.028       0.037
# log_byst            -0.0125      0.001    -12.687      0.000      -0.014      -0.011
# urgency              0.4237      0.005     88.777      0.000       0.414       0.433
# log_byst:urgency    -0.0608      0.005    -13.259      0.000      -0.070      -0.052
# pos                  0.0277      0.001     29.056      0.000       0.026       0.030
# ==============================================================================
# Omnibus:                     1306.266   Durbin-Watson:                   2.101
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1873.245
# Skew:                           0.479   Prob(JB):                         0.00
# Kurtosis:                       3.939   Cond. No.                         9.15
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# ------ gemma27
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.228
# Model:                            OLS   Adj. R-squared:                  0.228
# Method:                 Least Squares   F-statistic:                     2004.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:20   Log-Likelihood:                -8916.6
# No. Observations:               25000   AIC:                         1.784e+04
# Df Residuals:                   24995   BIC:                         1.788e+04
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.1538      0.005     33.275      0.000       0.145       0.163
# log_byst            -0.0447      0.002    -23.418      0.000      -0.048      -0.041
# urgency              0.4281      0.007     63.844      0.000       0.415       0.441
# log_byst:urgency    -0.1018      0.006    -16.148      0.000      -0.114      -0.089
# pos                 -0.0205      0.002    -11.865      0.000      -0.024      -0.017
# ==============================================================================
# Omnibus:                     3480.220   Durbin-Watson:                   2.262
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5161.142
# Skew:                           1.036   Prob(JB):                         0.00
# Kurtosis:                       3.813   Cond. No.                         9.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# ------ ministral8
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.356
# Model:                            OLS   Adj. R-squared:                  0.356
# Method:                 Least Squares   F-statistic:                     2127.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:20   Log-Likelihood:                 3872.6
# No. Observations:               25000   AIC:                            -7735.
# Df Residuals:                   24995   BIC:                            -7695.
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.1242      0.002     51.417      0.000       0.119       0.129
# log_byst            -0.0095      0.001     -8.583      0.000      -0.012      -0.007
# urgency              0.3498      0.005     74.064      0.000       0.341       0.359
# log_byst:urgency    -0.0322      0.005     -6.990      0.000      -0.041      -0.023
# pos                 -0.0094      0.001    -11.233      0.000      -0.011      -0.008
# ==============================================================================
# Omnibus:                     2425.967   Durbin-Watson:                   2.239
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3455.070
# Skew:                           0.768   Prob(JB):                         0.00
# Kurtosis:                       3.978   Cond. No.                         9.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# ------ qwen8
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.333
# Model:                            OLS   Adj. R-squared:                  0.333
# Method:                 Least Squares   F-statistic:                     4484.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:20   Log-Likelihood:                -4722.8
# No. Observations:               25000   AIC:                             9456.
# Df Residuals:                   24995   BIC:                             9496.
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.0251      0.003     -8.665      0.000      -0.031      -0.019
# log_byst            -0.0368      0.002    -21.422      0.000      -0.040      -0.033
# urgency              0.4229      0.006     75.611      0.000       0.412       0.434
# log_byst:urgency    -0.0634      0.006    -10.559      0.000      -0.075      -0.052
# pos                  0.0653      0.001     50.623      0.000       0.063       0.068
# ==============================================================================
# Omnibus:                     2239.933   Durbin-Watson:                   2.279
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2943.000
# Skew:                           0.773   Prob(JB):                         0.00
# Kurtosis:                       3.659   Cond. No.                         9.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# ------ qwen14
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.281
# Model:                            OLS   Adj. R-squared:                  0.281
# Method:                 Least Squares   F-statistic:                     2483.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:20   Log-Likelihood:                -7606.1
# No. Observations:               25000   AIC:                         1.522e+04
# Df Residuals:                   24995   BIC:                         1.526e+04
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.0615      0.004     16.674      0.000       0.054       0.069
# log_byst            -0.0284      0.002    -13.755      0.000      -0.032      -0.024
# urgency              0.4662      0.006     76.114      0.000       0.454       0.478
# log_byst:urgency    -0.0544      0.007     -7.649      0.000      -0.068      -0.040
# pos                  0.0119      0.001      8.265      0.000       0.009       0.015
# ==============================================================================
# Omnibus:                     2828.298   Durbin-Watson:                   2.260
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4075.540
# Skew:                           0.867   Prob(JB):                         0.00
# Kurtosis:                       3.950   Cond. No.                         9.25
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)

# %%
df_summary_10 = compare_model_coef(df_dict_10)
# Out:
# ------ gemma12
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.223
# Model:                            OLS   Adj. R-squared:                  0.223
# Method:                 Least Squares   F-statistic:                     5440.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:21   Log-Likelihood:                -3013.9
# No. Observations:               50000   AIC:                             6038.
# Df Residuals:                   49995   BIC:                             6082.
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.0200      0.002      9.400      0.000       0.016       0.024
# log_byst            -0.0078      0.000    -16.864      0.000      -0.009      -0.007
# urgency              0.3187      0.004     89.753      0.000       0.312       0.326
# log_byst:urgency    -0.0363      0.004     -8.204      0.000      -0.045      -0.028
# pos                 -0.0009      0.000     -2.246      0.025      -0.002      -0.000
# ==============================================================================
# Omnibus:                    15372.461   Durbin-Watson:                   2.123
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            42901.606
# Skew:                           1.648   Prob(JB):                         0.00
# Kurtosis:                       6.119   Cond. No.                         18.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# ------ qwen8
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.279
# Model:                            OLS   Adj. R-squared:                  0.279
# Method:                 Least Squares   F-statistic:                     6542.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:21   Log-Likelihood:                 3026.4
# No. Observations:               50000   AIC:                            -6043.
# Df Residuals:                   49995   BIC:                            -5999.
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.0667      0.002    -42.519      0.000      -0.070      -0.064
# log_byst            -0.0037      0.001     -5.663      0.000      -0.005      -0.002
# urgency              0.3128      0.003    103.949      0.000       0.307       0.319
# log_byst:urgency    -0.0697      0.004    -19.089      0.000      -0.077      -0.063
# pos                  0.0190      0.000     60.026      0.000       0.018       0.020
# ==============================================================================
# Omnibus:                    14874.264   Durbin-Watson:                   2.176
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            42394.634
# Skew:                           1.579   Prob(JB):                         0.00
# Kurtosis:                       6.222   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# ------ qwen14
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.232
# Model:                            OLS   Adj. R-squared:                  0.232
# Method:                 Least Squares   F-statistic:                     4668.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:21   Log-Likelihood:                -1988.0
# No. Observations:               50000   AIC:                             3986.
# Df Residuals:                   49995   BIC:                             4030.
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.0143      0.002      7.323      0.000       0.010       0.018
# log_byst            -0.0045      0.001     -7.029      0.000      -0.006      -0.003
# urgency              0.3269      0.003     96.209      0.000       0.320       0.334
# log_byst:urgency    -0.0561      0.005    -12.232      0.000      -0.065      -0.047
# pos              -2.696e-05      0.000     -0.068      0.946      -0.001       0.001
# ==============================================================================
# Omnibus:                    15380.758   Durbin-Watson:                   2.121
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            43770.265
# Skew:                           1.638   Prob(JB):                         0.00
# Kurtosis:                       6.206   Cond. No.                         19.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# ------ llama8
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.309
# Method:                 Least Squares   F-statistic:                     2793.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:21   Log-Likelihood:                 34142.
# No. Observations:               50000   AIC:                        -6.827e+04
# Df Residuals:                   49995   BIC:                        -6.823e+04
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.0641      0.001     59.115      0.000       0.062       0.066
# log_byst            -0.0071      0.000    -20.011      0.000      -0.008      -0.006
# urgency              0.1978      0.002     90.197      0.000       0.194       0.202
# log_byst:urgency    -0.0698      0.002    -43.023      0.000      -0.073      -0.067
# pos                 -0.0019      0.000     -9.868      0.000      -0.002      -0.002
# ==============================================================================
# Omnibus:                    24787.525   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           194399.384
# Skew:                           2.260   Prob(JB):                         0.00
# Kurtosis:                      11.537   Cond. No.                         18.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# ------ gemma27
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.194
# Model:                            OLS   Adj. R-squared:                  0.194
# Method:                 Least Squares   F-statistic:                     3726.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:21   Log-Likelihood:                -4455.7
# No. Observations:               50000   AIC:                             8921.
# Df Residuals:                   49995   BIC:                             8966.
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.0696      0.002     28.178      0.000       0.065       0.074
# log_byst            -0.0124      0.001    -17.261      0.000      -0.014      -0.011
# urgency              0.3063      0.004     85.527      0.000       0.299       0.313
# log_byst:urgency    -0.0901      0.004    -25.219      0.000      -0.097      -0.083
# pos                 -0.0090      0.000    -20.450      0.000      -0.010      -0.008
# ==============================================================================
# Omnibus:                    17578.083   Durbin-Watson:                   2.148
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            55477.333
# Skew:                           1.841   Prob(JB):                         0.00
# Kurtosis:                       6.615   Cond. No.                         18.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# ------ ministral14
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.362
# Model:                            OLS   Adj. R-squared:                  0.362
# Method:                 Least Squares   F-statistic:                     4731.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:21   Log-Likelihood:                 18548.
# No. Observations:               50000   AIC:                        -3.709e+04
# Df Residuals:                   49995   BIC:                        -3.704e+04
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.0020      0.001     -1.629      0.103      -0.004       0.000
# log_byst            -0.0025      0.000     -8.976      0.000      -0.003      -0.002
# urgency              0.2984      0.003    112.981      0.000       0.293       0.304
# log_byst:urgency    -0.0619      0.003    -22.106      0.000      -0.067      -0.056
# pos                  0.0053      0.000     20.832      0.000       0.005       0.006
# ==============================================================================
# Omnibus:                    18337.927   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            84991.750
# Skew:                           1.746   Prob(JB):                         0.00
# Kurtosis:                       8.348   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# ------ ministral8
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   prob   R-squared:                       0.160
# Model:                            OLS   Adj. R-squared:                  0.160
# Method:                 Least Squares   F-statistic:                     2098.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        11:59:21   Log-Likelihood:                 21325.
# No. Observations:               50000   AIC:                        -4.264e+04
# Df Residuals:                   49995   BIC:                        -4.260e+04
# Df Model:                           4
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.0198      0.001     19.163      0.000       0.018       0.022
# log_byst             0.0021      0.001      2.466      0.014       0.000       0.004
# urgency              0.1502      0.002     63.485      0.000       0.146       0.155
# log_byst:urgency    -0.0177      0.002     -7.682      0.000      -0.022      -0.013
# pos                  0.0082      0.000     42.421      0.000       0.008       0.009
# ==============================================================================
# Omnibus:                    20975.841   Durbin-Watson:                   2.469
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            89116.235
# Skew:                           2.088   Prob(JB):                         0.00
# Kurtosis:                       8.034   Cond. No.                         19.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)

# %%
def plot_coefficients(df_summary, effect, num_mails):

    plt.figure(figsize=(3.2, 3.5*0.7))

    if effect == "bystander":
        plt.errorbar(
            df_summary["beta byst"],
            df_summary["model"],
            xerr=[
                df_summary["beta byst"] - df_summary["ci_low byst"],
                df_summary["ci_high byst"] - df_summary["beta byst"]
            ],
            fmt="o",
            capsize=3,
            color = "black",
            linewidth = 1.5,
            markersize = 3
        )
    if effect == "interaction":
        plt.errorbar(
            df_summary["beta int"],
            df_summary["model"],
            xerr=[
                df_summary["beta int"] - df_summary["ci_low int"],
                df_summary["ci_high int"] - df_summary["beta int"]
            ],
            fmt="o",
            capsize=3,
            color = "black",
            linewidth = 1.5,
            markersize = 3
        )
        

    plt.axvline(0, linestyle="--", c = "r")
    if num_mails == 10:
        plt.xlabel("Coefficient value", fontsize = 10, labelpad = 8)
    if effect == "bystander":
        plt.ylabel("Model", fontsize = 10, labelpad = 8)
    else:
        plt.ylabel("*", fontsize = 10, labelpad = 8, c = "white")
    plt.yticks(fontsize = 10)
    plt.xticks(np.arange(-0.2, 0.11, 0.1), fontsize = 10)
    
    plt.tight_layout()
    loc = f"plots/advanced_choice/{effect}_coef_{num_mails}_a.pdf"
    plt.savefig(loc)
    plt.show()

# %%
summary_dicts = {2: df_summary_2,
                5: df_summary_5,
                10: df_summary_10}

for n_mails, df_dict in summary_dicts.items():

    print("Bystander", n_mails)
    plot_coefficients(df_dict, "bystander", n_mails)
    print("Interaction", n_mails)
    plot_coefficients(df_dict, "interaction", n_mails)
# Out:
# Bystander 2
# Interaction 2
# Bystander 5
# Interaction 5
# Bystander 10
# Interaction 10

# %% [markdown]
# ### Calculate Summary Scores

# %%
def calculate_area_under_curve(df_dict):
    """
    Calculate the area between the actual curve and a horizontal baseline
    set at the first column mean for each model.
    """
    area_scores = {}
    
    for model_name, df in df_dict.items():
        
        # Calculate average prob for each number of bystanders
        column_means = df.groupby("delta_b")["delta_prob"].mean()
        num_byst = column_means.index.astype(int)

        # Baseline: horizontal line at the first column mean
        baseline = column_means.iloc[0]
        baseline_curve = np.full_like(column_means, fill_value=baseline, dtype=float)

        # maximum curve would be starting at baseline, then going down to 0
        max_traj = [baseline] + [-1] * (len(num_byst) -1)

        # Area between the actual curve and the baseline
        actual_area = np.trapezoid(column_means, num_byst)
        baseline_area = np.trapezoid(baseline_curve, num_byst)
        area_between = baseline_area - actual_area

        # area between the baseline and the maximum curve
        maximum_area = np.trapezoid(max_traj, num_byst)
        max_area_between = baseline_area - maximum_area

        # normalize actual area by maximum area
        normalized_area = area_between / max_area_between

        area_scores[model_name] = normalized_area

    return area_scores

# %%
scores_noturgent = calculate_area_under_curve(df_dict_2_control)
scores_urgent = calculate_area_under_curve(df_dict_2_control_urgent)

# %%
summary_scores = pd.DataFrame([scores_noturgent, scores_urgent], index = ["choice_noturgent", "choice_urgent"])

# %%
summary_scores.to_csv("results/summary_choice.csv", index_label = "Experiment")
