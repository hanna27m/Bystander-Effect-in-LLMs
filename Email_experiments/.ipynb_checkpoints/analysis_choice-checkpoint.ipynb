# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import statsmodels.formula.api as smf
from input.plot_styles import family_colors, set_plot_style, model_order

# %%
set_plot_style()

# %%
model_dict = {"qwen8":"Qwen/Qwen3-8B",
             "qwen14": "Qwen/Qwen3-14B",
             "gemma12": "google/gemma-3-12b-it",
             "gemma27": "google/gemma-3-27b-it",
             "llama8": "meta-llama/Llama-3.1-8B-Instruct",
             "ministral14": "mistralai/Ministral-3-14B-Instruct-2512",
             "ministral8": "mistralai/Ministral-3-8B-Instruct-2512"}

# %% [markdown]
# ### Loading Data

# %%
def load_results_to_dict(num_mails, urgent=True):
    subfolder = "urgent" if urgent else "not_urgent"
    directory = f"results/results_choice/{num_mails}/{subfolder}"
    
    df_dict = {}
    
    # Check if directory exists
    if not os.path.exists(directory):
        print(f"Directory {directory} not found.")
        return df_dict

    # Iterate through files in the folder
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            # Extract model name from filename (e.g., 'answers_choose5_llama8.csv')
            # split by '_' and use the last part without '.csv'
            model_name = filename.split('_')[-1].replace('.csv', '')
            
            # Load the dataframe
            file_path = os.path.join(directory, filename)
            df_dict[model_name] = pd.read_csv(file_path)
            
            print(f"✓ Loaded {model_name}")
            
    return df_dict

# %%
# Usage
df_dict_2 = load_results_to_dict(num_mails=2, urgent=False)
df_dict_2_urgent = load_results_to_dict(num_mails=2, urgent=True)
# Out:
# ✓ Loaded gemma12
# ✓ Loaded gemma27
# ✓ Loaded llama8
# ✓ Loaded ministral14
# ✓ Loaded ministral8
# ✓ Loaded qwen14
# ✓ Loaded qwen8
# ✓ Loaded gemma12
# ✓ Loaded gemma27
# ✓ Loaded llama8
# ✓ Loaded ministral14
# ✓ Loaded ministral8
# ✓ Loaded qwen8
# ✓ Loaded qwen14

# %%
df_dict_5 = load_results_to_dict(num_mails=5, urgent=False)
df_dict_5_urgent = load_results_to_dict(num_mails=5, urgent=True)
# Out:
# ✓ Loaded gemma12
# ✓ Loaded gemma27
# ✓ Loaded llama8
# ✓ Loaded ministral14
# ✓ Loaded ministral8
# ✓ Loaded qwen14
# ✓ Loaded qwen8
# ✓ Loaded gemma12
# ✓ Loaded gemma27
# ✓ Loaded llama8
# ✓ Loaded ministral14
# ✓ Loaded ministral8
# ✓ Loaded qwen14
# ✓ Loaded qwen8

# %%
df_dict_10 = load_results_to_dict(num_mails=10, urgent= False)
df_dict_10_urgent = load_results_to_dict(num_mails=10, urgent= True)
# Out:
# ✓ Loaded gemma12
# ✓ Loaded gemma27
# ✓ Loaded ministral14
# ✓ Loaded qwen8
# ✓ Loaded ministral8
# ✓ Loaded llama8
# ✓ Loaded qwen14
# ✓ Loaded gemma12
# ✓ Loaded gemma27
# ✓ Loaded llama8
# ✓ Loaded qwen14
# ✓ Loaded ministral8
# ✓ Loaded qwen8
# ✓ Loaded ministral14

# %% [markdown]
# ### Visualizing results

# %%
def process_and_plot_together(df_dict, color_map, num_mails, urgent):
    plt.figure(figsize=(3.2, 3.5*0.7))
    processed_dfs = {}

    for model_name, df in df_dict.items():
        # --- Recode Logic ---
        bystander_condition = df["bystander condition"]
        df_recode = df.eq(bystander_condition, axis=0).astype(int)
        df_recode.drop(columns=["bystander condition"], inplace=True)
        
        # Calculate means and Standard Error
        column_means = df_recode.mean(axis=0)
        # Standard Error (SE) = Standard Deviation / sqrt(n)
        column_se = df_recode.sem(axis=0) 

        line_color = color_map.get(model_name, "gray")
        
        # Use errorbar instead of plot
        plt.errorbar(column_means.index.astype(int), 
                     column_means, 
                     yerr=column_se,          # This adds the vertical bars
                     marker='o', 
                     ms=3,
                     linestyle='-', 
                     label=model_name, 
                     color=line_color, 
                     linewidth=1.5,
                     capsize=3,
                     capthick =1
                    )               
        
        processed_dfs[model_name] = df_recode

    # Plot Styling
    #plt.title("Bystander Effect Comparison across Models", fontsize=16)
    #plt.suptitle(f"Mails to choose from = {num_mails}, urgent = {urgent}")
    if num_mails == 10:
        plt.xlabel("Number of additional recipients", fontsize = 10, labelpad = 8)
        if urgent:
            plt.ylabel(r" * ", fontsize= 10, labelpad = 8, c = "white")
        else:
            plt.ylabel(r"$P(\mathrm{Bystander\ email})$", fontsize=10, labelpad = 8)
    else:
        plt.xlabel(r"", fontsize= 10, labelpad = 8, c = "white")
        if urgent:
            plt.ylabel(r" * ", fontsize= 10, labelpad = 8, c = "white")
        else:
            plt.ylabel(r"$P(\mathrm{Bystander\ email})$", fontsize=10, labelpad = 8)
    plt.xticks(np.arange(0, 21, 2), fontsize = 10)
    plt.yticks(fontsize =10)
    plt.ylim(0, 0.8) 
    plt.axhline(y=1/num_mails, color='r', linestyle='--', linewidth=1)
    plt.grid(True, linestyle='--', alpha=0.5)
    #plt.legend(title="Models")
    plt.tight_layout()
    plt.savefig(f"plots/choice/overview_{num_mails}_urgent{urgent}.pdf")
    plt.show()
    

    return processed_dfs

# %%
df_dict_recode_5 = process_and_plot_together(df_dict_5, family_colors, 5, False)

# %%
df_dict_recode_5_urgent = process_and_plot_together(df_dict_5_urgent, family_colors, 5, urgent = True)

# %%
df_dict_recode_2 = process_and_plot_together(df_dict_2, family_colors, 2, urgent = False)

# %%
df_dict_recode_2_urgent = process_and_plot_together(df_dict_2_urgent, family_colors, 2, True)

# %%
df_dict_recode_10 = process_and_plot_together(df_dict_10, family_colors, 10, False)

# %%
df_dict_recode_10_urgent = process_and_plot_together(df_dict_10_urgent, family_colors, 10, True)

# %%
labels = list(family_colors.keys())
handles = [plt.Rectangle((0,0),1,1, color=family_colors[label]) for label in labels]

# Erstelle ein "leeres" Bild nur für die Legende
fig_leg = plt.figure(figsize=(8, 0.5)) # Breit und flach
ax_leg = fig_leg.add_subplot(111)
ax_leg.legend(handles, labels, loc='center', ncol=4, frameon=False, fontsize = 18)
ax_leg.axis('off') # Achsen verstecken

# Speichern
plt.savefig('plots/legend.pdf', bbox_inches='tight')

# %% [markdown]
# ### Regression Analysis

# %%
def perform_regression(result_dfs, result_dfs_urgent):
    # create one big dataset 
    all_dfs = []
    
    for model, df in result_dfs.items():
        df["urgency"] = 0
        df["model"] = model
        df["round"] = df.index
        all_dfs.append(df)
    
    for model, df in result_dfs_urgent.items():
        df["urgency"] = 1
        df["model"] = model
        df["round"] = df.index + 1000
        all_dfs.append(df)
    
    df_all = pd.concat(all_dfs, ignore_index=True)
    
    df_all = df_all.melt(
        id_vars=["model", "urgency", "round"],
        var_name="bystanders",
        value_name="chosen"
    )
    
    df_all["bystanders"] = df_all["bystanders"].astype(int)
    df_all["log_bystanders"] = np.log1p(df_all["bystanders"]) # log transformation

    results = {}

    # analyse results per model
    for model, group in df_all.groupby("model"):
        group = group.copy().reset_index(drop=True)
        
        formula = "chosen ~ log_bystanders * urgency"
        
        model_fit = smf.logit(formula, data=group).fit(
            cov_type="cluster",
            cov_kwds={"groups": group["round"]},
            disp=False
        )
        
        results[model] = model_fit
        
        print(f"\n{'='*50}")
        print(f"Model: {model}")
        print(f"{'='*50}")
        print(model_fit.summary())
    
    return results

# %%
reg_results_2 = perform_regression(df_dict_recode_2, df_dict_recode_2_urgent)
# Out:
# ==================================================
# Model: gemma12
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                  0.1476
# Time:                        11:20:18   Log-Likelihood:                -14063.
# converged:                       True   LL-Null:                       -16498.
# Covariance Type:              cluster   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.2998      0.068      4.397      0.000       0.166       0.433
# log_bystanders            -1.3867      0.064    -21.694      0.000      -1.512      -1.261
# urgency                   -0.2068      0.091     -2.275      0.023      -0.385      -0.029
# log_bystanders:urgency     0.5226      0.076      6.895      0.000       0.374       0.671
# ==========================================================================================
#
# ==================================================
# Model: gemma27
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                  0.1172
# Time:                        11:20:18   Log-Likelihood:                -14722.
# converged:                       True   LL-Null:                       -16677.
# Covariance Type:              cluster   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0144      0.060      0.238      0.812      -0.104       0.133
# log_bystanders            -1.0220      0.052    -19.805      0.000      -1.123      -0.921
# urgency                    0.1478      0.085      1.738      0.082      -0.019       0.314
# log_bystanders:urgency     0.0239      0.069      0.345      0.730      -0.112       0.160
# ==========================================================================================
#
# ==================================================
# Model: llama8
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                  0.1561
# Time:                        11:20:18   Log-Likelihood:                -14972.
# converged:                       True   LL-Null:                       -17742.
# Covariance Type:              cluster   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.3842      0.075      5.095      0.000       0.236       0.532
# log_bystanders            -1.2213      0.050    -24.447      0.000      -1.319      -1.123
# urgency                    0.2139      0.110      1.943      0.052      -0.002       0.430
# log_bystanders:urgency     0.0951      0.066      1.440      0.150      -0.034       0.224
# ==========================================================================================
#
# ==================================================
# Model: ministral14
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.09981
# Time:                        11:20:18   Log-Likelihood:                -23250.
# converged:                       True   LL-Null:                       -25828.
# Covariance Type:              cluster   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  1.3869      0.085     16.282      0.000       1.220       1.554
# log_bystanders            -1.1749      0.037    -31.672      0.000      -1.248      -1.102
# urgency                   -0.6169      0.113     -5.462      0.000      -0.838      -0.396
# log_bystanders:urgency     0.5005      0.046     10.945      0.000       0.411       0.590
# ==========================================================================================
#
# ==================================================
# Model: ministral8
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.01244
# Time:                        11:20:18   Log-Likelihood:                -28742.
# converged:                       True   LL-Null:                       -29104.
# Covariance Type:              cluster   LLR p-value:                1.335e-156
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.9459      0.069     13.703      0.000       0.811       1.081
# log_bystanders            -0.4148      0.023    -17.662      0.000      -0.461      -0.369
# urgency                   -0.4094      0.096     -4.281      0.000      -0.597      -0.222
# log_bystanders:urgency     0.1817      0.029      6.244      0.000       0.125       0.239
# ==========================================================================================
#
# ==================================================
# Model: qwen14
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.07188
# Time:                        11:20:19   Log-Likelihood:                -25845.
# converged:                       True   LL-Null:                       -27846.
# Covariance Type:              cluster   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.1867      0.057      3.257      0.001       0.074       0.299
# log_bystanders            -0.6085      0.041    -14.691      0.000      -0.690      -0.527
# urgency                    0.3719      0.082      4.515      0.000       0.210       0.533
# log_bystanders:urgency     0.3532      0.050      7.028      0.000       0.255       0.452
# ==========================================================================================
#
# ==================================================
# Model: qwen8
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.05842
# Time:                        11:20:19   Log-Likelihood:                -22911.
# converged:                       True   LL-Null:                       -24332.
# Covariance Type:              cluster   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.4417      0.067      6.627      0.000       0.311       0.572
# log_bystanders            -0.8152      0.028    -28.865      0.000      -0.871      -0.760
# urgency                   -0.1648      0.093     -1.770      0.077      -0.347       0.018
# log_bystanders:urgency     0.2899      0.038      7.582      0.000       0.215       0.365
# ==========================================================================================

# %%
reg_results_5 = perform_regression(df_dict_recode_5, df_dict_recode_5_urgent)
# Out:
# ==================================================
# Model: gemma12
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                  0.1336
# Time:                        11:20:20   Log-Likelihood:                -19165.
# converged:                       True   LL-Null:                       -22119.
# Covariance Type:              cluster   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -0.9226      0.075    -12.226      0.000      -1.071      -0.775
# log_bystanders            -0.7884      0.046    -17.060      0.000      -0.879      -0.698
# urgency                    0.5094      0.095      5.385      0.000       0.324       0.695
# log_bystanders:urgency     0.7122      0.051     14.034      0.000       0.613       0.812
# ==========================================================================================
#
# ==================================================
# Model: gemma27
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.01780
# Time:                        11:20:20   Log-Likelihood:                -16849.
# converged:                       True   LL-Null:                       -17155.
# Covariance Type:              cluster   LLR p-value:                4.416e-132
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -1.2407      0.080    -15.561      0.000      -1.397      -1.084
# log_bystanders            -0.3804      0.047     -8.023      0.000      -0.473      -0.287
# urgency                    0.2178      0.107      2.042      0.041       0.009       0.427
# log_bystanders:urgency     0.1035      0.059      1.753      0.080      -0.012       0.219
# ==========================================================================================
#
# ==================================================
# Model: llama8
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.03989
# Time:                        11:20:20   Log-Likelihood:                -8434.8
# converged:                       True   LL-Null:                       -8785.3
# Covariance Type:              cluster   LLR p-value:                1.297e-151
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -1.8388      0.084    -21.954      0.000      -2.003      -1.675
# log_bystanders            -0.6424      0.066     -9.711      0.000      -0.772      -0.513
# urgency                    0.2601      0.116      2.246      0.025       0.033       0.487
# log_bystanders:urgency     0.0860      0.083      1.037      0.300      -0.077       0.249
# ==========================================================================================
#
# ==================================================
# Model: ministral14
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.02029
# Time:                        11:20:20   Log-Likelihood:                -26356.
# converged:                       True   LL-Null:                       -26902.
# Covariance Type:              cluster   LLR p-value:                2.080e-236
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -0.2223      0.065     -3.410      0.001      -0.350      -0.095
# log_bystanders            -0.3337      0.025    -13.123      0.000      -0.384      -0.284
# urgency                    0.3030      0.087      3.484      0.000       0.133       0.473
# log_bystanders:urgency     0.0983      0.034      2.904      0.004       0.032       0.165
# ==========================================================================================
#
# ==================================================
# Model: ministral8
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.02872
# Time:                        11:20:20   Log-Likelihood:                -26852.
# converged:                       True   LL-Null:                       -27646.
# Covariance Type:              cluster   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -0.2128      0.063     -3.383      0.001      -0.336      -0.090
# log_bystanders            -0.3334      0.023    -14.572      0.000      -0.378      -0.289
# urgency                    0.0400      0.085      0.472      0.637      -0.126       0.206
# log_bystanders:urgency     0.3246      0.030     10.662      0.000       0.265       0.384
# ==========================================================================================
#
# ==================================================
# Model: qwen14
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.02969
# Time:                        11:20:20   Log-Likelihood:                -27092.
# converged:                       True   LL-Null:                       -27921.
# Covariance Type:              cluster   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -1.4453      0.066    -21.782      0.000      -1.575      -1.315
# log_bystanders             0.3010      0.025     12.020      0.000       0.252       0.350
# urgency                    0.2795      0.090      3.106      0.002       0.103       0.456
# log_bystanders:urgency     0.1400      0.033      4.278      0.000       0.076       0.204
# ==========================================================================================
#
# ==================================================
# Model: qwen8
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.03891
# Time:                        11:20:20   Log-Likelihood:                -18708.
# converged:                       True   LL-Null:                       -19466.
# Covariance Type:              cluster   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -2.0596      0.089    -23.262      0.000      -2.233      -1.886
# log_bystanders            -0.0247      0.036     -0.692      0.489      -0.095       0.045
# urgency                    0.2861      0.124      2.304      0.021       0.043       0.530
# log_bystanders:urgency     0.3103      0.045      6.905      0.000       0.222       0.398
# ==========================================================================================

# %%
reg_results_5 = perform_regression(df_dict_recode_5, df_dict_recode_5_urgent)
# Out:
# ==================================================
# Model: gemma12
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                  0.1336
# Time:                        11:20:20   Log-Likelihood:                -19165.
# converged:                       True   LL-Null:                       -22119.
# Covariance Type:              cluster   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -0.9226      0.075    -12.226      0.000      -1.071      -0.775
# log_bystanders            -0.7884      0.046    -17.060      0.000      -0.879      -0.698
# urgency                    0.5094      0.095      5.385      0.000       0.324       0.695
# log_bystanders:urgency     0.7122      0.051     14.034      0.000       0.613       0.812
# ==========================================================================================
#
# ==================================================
# Model: gemma27
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.01780
# Time:                        11:20:21   Log-Likelihood:                -16849.
# converged:                       True   LL-Null:                       -17155.
# Covariance Type:              cluster   LLR p-value:                4.416e-132
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -1.2407      0.080    -15.561      0.000      -1.397      -1.084
# log_bystanders            -0.3804      0.047     -8.023      0.000      -0.473      -0.287
# urgency                    0.2178      0.107      2.042      0.041       0.009       0.427
# log_bystanders:urgency     0.1035      0.059      1.753      0.080      -0.012       0.219
# ==========================================================================================
#
# ==================================================
# Model: llama8
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.03989
# Time:                        11:20:21   Log-Likelihood:                -8434.8
# converged:                       True   LL-Null:                       -8785.3
# Covariance Type:              cluster   LLR p-value:                1.297e-151
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -1.8388      0.084    -21.954      0.000      -2.003      -1.675
# log_bystanders            -0.6424      0.066     -9.711      0.000      -0.772      -0.513
# urgency                    0.2601      0.116      2.246      0.025       0.033       0.487
# log_bystanders:urgency     0.0860      0.083      1.037      0.300      -0.077       0.249
# ==========================================================================================
#
# ==================================================
# Model: ministral14
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.02029
# Time:                        11:20:21   Log-Likelihood:                -26356.
# converged:                       True   LL-Null:                       -26902.
# Covariance Type:              cluster   LLR p-value:                2.080e-236
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -0.2223      0.065     -3.410      0.001      -0.350      -0.095
# log_bystanders            -0.3337      0.025    -13.123      0.000      -0.384      -0.284
# urgency                    0.3030      0.087      3.484      0.000       0.133       0.473
# log_bystanders:urgency     0.0983      0.034      2.904      0.004       0.032       0.165
# ==========================================================================================
#
# ==================================================
# Model: ministral8
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.02872
# Time:                        11:20:21   Log-Likelihood:                -26852.
# converged:                       True   LL-Null:                       -27646.
# Covariance Type:              cluster   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -0.2128      0.063     -3.383      0.001      -0.336      -0.090
# log_bystanders            -0.3334      0.023    -14.572      0.000      -0.378      -0.289
# urgency                    0.0400      0.085      0.472      0.637      -0.126       0.206
# log_bystanders:urgency     0.3246      0.030     10.662      0.000       0.265       0.384
# ==========================================================================================
#
# ==================================================
# Model: qwen14
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.02969
# Time:                        11:20:21   Log-Likelihood:                -27092.
# converged:                       True   LL-Null:                       -27921.
# Covariance Type:              cluster   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -1.4453      0.066    -21.782      0.000      -1.575      -1.315
# log_bystanders             0.3010      0.025     12.020      0.000       0.252       0.350
# urgency                    0.2795      0.090      3.106      0.002       0.103       0.456
# log_bystanders:urgency     0.1400      0.033      4.278      0.000       0.076       0.204
# ==========================================================================================
#
# ==================================================
# Model: qwen8
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.03891
# Time:                        11:20:21   Log-Likelihood:                -18708.
# converged:                       True   LL-Null:                       -19466.
# Covariance Type:              cluster   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -2.0596      0.089    -23.262      0.000      -2.233      -1.886
# log_bystanders            -0.0247      0.036     -0.692      0.489      -0.095       0.045
# urgency                    0.2861      0.124      2.304      0.021       0.043       0.530
# log_bystanders:urgency     0.3103      0.045      6.905      0.000       0.222       0.398
# ==========================================================================================

# %%
reg_results_10 = perform_regression(df_dict_recode_10, df_dict_recode_10_urgent)
# Out:
# ==================================================
# Model: gemma12
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                  0.1460
# Time:                        11:20:21   Log-Likelihood:                -23568.
# converged:                       True   LL-Null:                       -27596.
# Covariance Type:              cluster   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -1.8858      0.096    -19.575      0.000      -2.075      -1.697
# log_bystanders             0.1609      0.034      4.671      0.000       0.093       0.228
# urgency                    0.6963      0.115      6.050      0.000       0.471       0.922
# log_bystanders:urgency     0.4935      0.043     11.447      0.000       0.409       0.578
# ==========================================================================================
#
# ==================================================
# Model: gemma27
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.06485
# Time:                        11:20:22   Log-Likelihood:                -19582.
# converged:                       True   LL-Null:                       -20940.
# Covariance Type:              cluster   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -1.9866      0.096    -20.589      0.000      -2.176      -1.798
# log_bystanders            -0.1006      0.044     -2.301      0.021      -0.186      -0.015
# urgency                    0.9589      0.116      8.282      0.000       0.732       1.186
# log_bystanders:urgency     0.1788      0.050      3.609      0.000       0.082       0.276
# ==========================================================================================
#
# ==================================================
# Model: llama8
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.01142
# Time:                        11:20:22   Log-Likelihood:                -14879.
# converged:                       True   LL-Null:                       -15051.
# Covariance Type:              cluster   LLR p-value:                 3.375e-74
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -2.7711      0.118    -23.454      0.000      -3.003      -2.540
# log_bystanders             0.2435      0.044      5.529      0.000       0.157       0.330
# urgency                    0.1877      0.162      1.162      0.245      -0.129       0.504
# log_bystanders:urgency     0.0795      0.059      1.359      0.174      -0.035       0.194
# ==========================================================================================
#
# ==================================================
# Model: ministral14
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.03672
# Time:                        11:20:22   Log-Likelihood:                -27999.
# converged:                       True   LL-Null:                       -29067.
# Covariance Type:              cluster   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -0.6281      0.058    -10.870      0.000      -0.741      -0.515
# log_bystanders             0.0434      0.019      2.226      0.026       0.005       0.082
# urgency                    0.4625      0.075      6.133      0.000       0.315       0.610
# log_bystanders:urgency     0.1911      0.028      6.922      0.000       0.137       0.245
# ==========================================================================================
#
# ==================================================
# Model: ministral8
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.02706
# Time:                        11:20:22   Log-Likelihood:                -22525.
# converged:                       True   LL-Null:                       -23151.
# Covariance Type:              cluster   LLR p-value:                2.590e-271
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -1.4295      0.072    -19.960      0.000      -1.570      -1.289
# log_bystanders            -0.0822      0.015     -5.421      0.000      -0.112      -0.052
# urgency                    0.6630      0.090      7.386      0.000       0.487       0.839
# log_bystanders:urgency     0.0732      0.021      3.497      0.000       0.032       0.114
# ==========================================================================================
#
# ==================================================
# Model: qwen14
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                 0.05916
# Time:                        11:20:22   Log-Likelihood:                -27316.
# converged:                       True   LL-Null:                       -29034.
# Covariance Type:              cluster   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -1.7020      0.064    -26.709      0.000      -1.827      -1.577
# log_bystanders             0.8007      0.028     28.544      0.000       0.746       0.856
# urgency                    0.3604      0.085      4.223      0.000       0.193       0.528
# log_bystanders:urgency    -0.0876      0.038     -2.322      0.020      -0.162      -0.014
# ==========================================================================================
#
# ==================================================
# Model: qwen8
# ==================================================
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 chosen   No. Observations:                42000
# Model:                          Logit   Df Residuals:                    41996
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 05 May 2026   Pseudo R-squ.:                0.007851
# Time:                        11:20:22   Log-Likelihood:                -18969.
# converged:                       True   LL-Null:                       -19119.
# Covariance Type:              cluster   LLR p-value:                 9.028e-65
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -2.1744      0.096    -22.720      0.000      -2.362      -1.987
# log_bystanders             0.2028      0.034      5.935      0.000       0.136       0.270
# urgency                    0.1159      0.135      0.860      0.390      -0.148       0.380
# log_bystanders:urgency     0.0667      0.044      1.516      0.130      -0.020       0.153
# ==========================================================================================

# %%
def plot_coefficients(model_fits, num_mails, effect="bystander", save_path=None):
    """
    results_by_size: dict {choice_size: {model_name: fitted_logit}}
    effect: "bystander" or "interaction"
    """
    
    param_map = {
        "bystander": "log_bystanders",
        "interaction": "log_bystanders:urgency"
    }
    param = param_map[effect]

    # collect coefficients across all models
    rows = []
    for model_name, fit in model_fits.items():
        coef = fit.params[param]
        ci_low, ci_high = fit.conf_int().loc[param]
        rows.append({
            "model": model_name,
            "coef": coef,
            "ci_low": ci_low,
            "ci_high": ci_high,
        })

    coef_df = pd.DataFrame(rows)
        
    # sort by defined model order
    coef_df["model"] = pd.Categorical(
        coef_df["model"], categories=model_order, ordered=True
    )
    coef_df = coef_df.sort_values("model")

    plt.figure(figsize=(3.2, 3.5*0.7))
    
    plt.errorbar(
        coef_df["coef"],
        coef_df["model"],
        xerr=[
            coef_df["coef"] - coef_df["ci_low"],
            coef_df["ci_high"] - coef_df["coef"]
        ],
        fmt="o",
        capsize=3,
        color = "black",
        linewidth = 1.5,
        markersize = 3
    )
    
    plt.axvline(0, linestyle="--", c = "r")
    if num_mails == 10:
        plt.xlabel("Coefficient value", fontsize = 10, labelpad = 8)
    if effect == "bystander":
        plt.ylabel("Model", fontsize = 10, labelpad = 8)
    else:
        plt.ylabel("*", fontsize = 10, labelpad = 8, c = "white")
    plt.yticks(fontsize = 10)
    plt.xticks(np.arange(-1.5, 1.5, 0.5), fontsize = 10)
    plt.xlim(-1.6, 1.3)
    #plt.title("Interaction between bystanders and urgency")
    
    plt.tight_layout()
    loc = f"plots/choice/{effect}_coef_{num_mails}.pdf"
    plt.savefig(loc)
    plt.show()

# %%
plot_coefficients(reg_results_2, 2)

# %%
plot_coefficients(reg_results_5, 5)

# %%
plot_coefficients(reg_results_10, 10)

# %%
plot_coefficients(reg_results_2, 2, "interaction")

# %%
plot_coefficients(reg_results_5, 5, "interaction")

# %%
plot_coefficients(reg_results_10, 10, "interaction")
