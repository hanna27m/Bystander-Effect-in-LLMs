# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import scipy
from input.plot_styles import family_colors, set_plot_style, model_order, FULL_WIDTH, HALF_WIDTH,GOLDEN_RATIO

# %%
set_plot_style()

# %%
model_dict = {"qwen8":"Qwen/Qwen3-8B",
             "qwen14": "Qwen/Qwen3-14B",
             "gemma12": "google/gemma-3-12b-it",
             "gemma27": "google/gemma-3-27b-it",
             "llama8": "meta-llama/Llama-3.1-8B-Instruct",
             "ministral14": "mistralai/Ministral-3-14B-Instruct-2512",
             "ministral8": "mistralai/Ministral-3-8B-Instruct-2512"}

# %% [markdown]
# ### Loading results

# %%
def load_results_to_dict(urgent):
    subfolder = "urgent" if urgent else "not_urgent"
    directory = f"results/results_yesno/{subfolder}"
    
    df_dict = {}
    
    # Check if directory exists
    if not os.path.exists(directory):
        print(f"Directory {directory} not found.")
        return df_dict

    # Iterate through files in the folder
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            # Extract model name from filename (e.g., 'answers_choose5_llama8.csv')
            # split by '_' and use the last part without '.csv'
            model_name = filename.split('_')[-1].replace('.csv', '')
            
            # Load the dataframe
            file_path = os.path.join(directory, filename)
            df_dict[model_name] = pd.read_csv(file_path)
            
            print(f"✓ Loaded {model_name}")
            
    return df_dict

# %%
result_dfs  = load_results_to_dict(False)
result_dfs_urgent = load_results_to_dict(True)
# Out:
# ✓ Loaded qwen8
# ✓ Loaded gemma12
# ✓ Loaded gemma27
# ✓ Loaded llama8
# ✓ Loaded ministral14
# ✓ Loaded ministral8
# ✓ Loaded qwen14
# ✓ Loaded gemma12
# ✓ Loaded gemma27
# ✓ Loaded llama8
# ✓ Loaded ministral14
# ✓ Loaded ministral8
# ✓ Loaded qwen14
# ✓ Loaded qwen8

# %% [markdown]
# ### Plotting results

# %%
def process_and_plot_together(df_dict, color_map, urgent):
    plt.figure(figsize=(3.2, 3.5*0.7))
    processed_dfs = {}

    for model_name, df in df_dict.items():
        
        # Calculate means and Standard Error
        column_means = df.mean(axis=0)
        # Standard Error (SE) = Standard Deviation / sqrt(n)
        column_se = df.sem(axis=0) 

        line_color = color_map.get(model_name, "gray")
        
        # Plotting mean with errorbars
        plt.errorbar(column_means.index.astype(int), 
                     column_means, 
                     yerr=column_se,         
                     marker='o', 
                     ms=3,
                     linestyle='-', 
                     label=model_name, 
                     color=line_color, 
                     linewidth=1.5,
                     capsize=3,
                     capthick =1
                    )  
        

    # Plot Styling
    #plt.title("Bystander Effect Comparison across Models", fontsize=16)
    plt.xlabel("Number of additional recipients", fontsize=10, labelpad = 8)
    plt.xticks(np.arange(0, 21, 2), fontsize = 10)
    plt.yticks(fontsize = 10)
    if urgent:
        plt.ylabel(r" * ", fontsize= 10, labelpad = 8, c = "white")
    else:
        plt.ylabel(r"Normalized $P(\mathrm{Yes})$", fontsize= 10, labelpad = 8)
    plt.ylim(0, 1.1) 
    plt.axhline(y= 1, color='r', linestyle='--', linewidth=1)
    plt.grid(True, linestyle='--', alpha=0.5)
    #plt.legend(title="Models")
    plt.tight_layout()
    plt.savefig(f"plots/yesno/overview_urgent{urgent}.pdf")
    plt.show()

# %%
process_and_plot_together(result_dfs, family_colors, urgent = False)

# %%
process_and_plot_together(result_dfs_urgent, family_colors, urgent = True)

# %% [markdown]
# ### Analysing results

# %%
### first create one big dataset

all_dfs = []

for model, df in result_dfs.items():

    df["urgency"] = 0
    df["model"] = model
    df["round"] = df.index
    all_dfs.append(df)

for model, df in result_dfs_urgent.items():

    df["urgency"] = 1
    df["model"] = model
    df["round"] = df.index + 1000
    all_dfs.append(df)

df_all = pd.concat(all_dfs, ignore_index=True)

# %%
### now convert to long format

df_all = df_all.melt(
    id_vars=["model", "urgency", "round"],
    var_name="bystanders",
    value_name="prob_yes"
)

# make sure bystanders is numeric
df_all["bystanders"] = df_all["bystanders"].astype(int)

# %%
import statsmodels.formula.api as smf

results = {}

for m in df_all["model"].unique():
    df_m = df_all[df_all["model"] == m].copy()
    df_m["log_bystanders"] = np.log(df_m["bystanders"] + 1)

    res = smf.ols(
            formula="prob_yes ~ log_bystanders * urgency",
            data=df_m
        ).fit(cov_type="cluster", cov_kwds={"groups": df_m["round"]})

    results[m] = res
    print(f"\n=== {m} ===")
    print(res.summary())
# Out:
# === qwen8 ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               prob_yes   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     341.4
# Date:                Tue, 05 May 2026   Prob (F-statistic):          5.79e-179
# Time:                        10:13:10   Log-Likelihood:                -9490.3
# No. Observations:               42000   AIC:                         1.899e+04
# Df Residuals:                   41996   BIC:                         1.902e+04
# Df Model:                           3
# Covariance Type:              cluster
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  1.1105      0.005    211.547      0.000       1.100       1.121
# log_bystanders            -0.1183      0.005    -24.457      0.000      -0.128      -0.109
# urgency                   -0.0368      0.007     -5.093      0.000      -0.051      -0.023
# log_bystanders:urgency     0.0226      0.007      3.376      0.001       0.009       0.036
# ==============================================================================
# Omnibus:                    13417.583   Durbin-Watson:                   1.901
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            31886.220
# Skew:                          -1.857   Prob(JB):                         0.00
# Kurtosis:                       5.105   Cond. No.                         20.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
#
# === gemma12 ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               prob_yes   R-squared:                       0.143
# Model:                            OLS   Adj. R-squared:                  0.143
# Method:                 Least Squares   F-statistic:                     625.4
# Date:                Tue, 05 May 2026   Prob (F-statistic):          1.12e-286
# Time:                        10:13:10   Log-Likelihood:                -19064.
# No. Observations:               42000   AIC:                         3.814e+04
# Df Residuals:                   41996   BIC:                         3.817e+04
# Df Model:                           3
# Covariance Type:              cluster
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  1.1239      0.009    120.951      0.000       1.106       1.142
# log_bystanders            -0.2083      0.006    -33.805      0.000      -0.220      -0.196
# urgency                   -0.0120      0.011     -1.054      0.292      -0.034       0.010
# log_bystanders:urgency     0.0588      0.008      6.969      0.000       0.042       0.075
# ==============================================================================
# Omnibus:                     6298.176   Durbin-Watson:                   1.907
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5337.212
# Skew:                          -0.787   Prob(JB):                         0.00
# Kurtosis:                       2.245   Cond. No.                         20.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
#
# === gemma27 ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               prob_yes   R-squared:                       0.188
# Model:                            OLS   Adj. R-squared:                  0.188
# Method:                 Least Squares   F-statistic:                     1283.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        10:13:10   Log-Likelihood:                -24689.
# No. Observations:               42000   AIC:                         4.939e+04
# Df Residuals:                   41996   BIC:                         4.942e+04
# Df Model:                           3
# Covariance Type:              cluster
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  1.0981      0.008    130.853      0.000       1.082       1.115
# log_bystanders            -0.2625      0.006    -46.032      0.000      -0.274      -0.251
# urgency                    0.0344      0.011      3.192      0.001       0.013       0.056
# log_bystanders:urgency     0.0023      0.009      0.276      0.783      -0.014       0.019
# ==============================================================================
# Omnibus:                   262460.945   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3897.331
# Skew:                           0.063   Prob(JB):                         0.00
# Kurtosis:                       1.513   Cond. No.                         20.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
#
# === llama8 ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               prob_yes   R-squared:                       0.164
# Model:                            OLS   Adj. R-squared:                  0.164
# Method:                 Least Squares   F-statistic:                     248.6
# Date:                Tue, 05 May 2026   Prob (F-statistic):          4.36e-137
# Time:                        10:13:10   Log-Likelihood:                 51971.
# No. Observations:               42000   AIC:                        -1.039e+05
# Df Residuals:                   41996   BIC:                        -1.039e+05
# Df Model:                           3
# Covariance Type:              cluster
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0319      0.002     20.848      0.000       0.029       0.035
# log_bystanders            -0.0073      0.001    -13.755      0.000      -0.008      -0.006
# urgency                    0.1125      0.006     18.288      0.000       0.100       0.125
# log_bystanders:urgency    -0.0326      0.002    -18.340      0.000      -0.036      -0.029
# ==============================================================================
# Omnibus:                    43315.509   Durbin-Watson:                   2.100
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2693240.504
# Skew:                           5.227   Prob(JB):                         0.00
# Kurtosis:                      40.812   Cond. No.                         20.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
#
# === ministral14 ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               prob_yes   R-squared:                       0.301
# Model:                            OLS   Adj. R-squared:                  0.300
# Method:                 Least Squares   F-statistic:                     2337.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        10:13:10   Log-Likelihood:                 39145.
# No. Observations:               42000   AIC:                        -7.828e+04
# Df Residuals:                   41996   BIC:                        -7.825e+04
# Df Model:                           3
# Covariance Type:              cluster
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.4016      0.004     98.670      0.000       0.394       0.410
# log_bystanders            -0.0703      0.001    -57.138      0.000      -0.073      -0.068
# urgency                    0.0292      0.007      4.140      0.000       0.015       0.043
# log_bystanders:urgency    -0.0151      0.002     -7.676      0.000      -0.019      -0.011
# ==============================================================================
# Omnibus:                     5684.091   Durbin-Watson:                   1.871
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10806.243
# Skew:                           0.866   Prob(JB):                         0.00
# Kurtosis:                       4.783   Cond. No.                         20.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
#
# === ministral8 ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               prob_yes   R-squared:                       0.295
# Model:                            OLS   Adj. R-squared:                  0.295
# Method:                 Least Squares   F-statistic:                     3831.
# Date:                Tue, 05 May 2026   Prob (F-statistic):               0.00
# Time:                        10:13:10   Log-Likelihood:                -5259.5
# No. Observations:               42000   AIC:                         1.053e+04
# Df Residuals:                   41996   BIC:                         1.056e+04
# Df Model:                           3
# Covariance Type:              cluster
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.9563      0.007    132.275      0.000       0.942       0.970
# log_bystanders            -0.2012      0.003    -70.988      0.000      -0.207      -0.196
# urgency                   -0.1163      0.013     -8.728      0.000      -0.142      -0.090
# log_bystanders:urgency    -0.0085      0.004     -2.004      0.045      -0.017      -0.000
# ==============================================================================
# Omnibus:                     3231.241   Durbin-Watson:                   1.915
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1808.275
# Skew:                           0.362   Prob(JB):                         0.00
# Kurtosis:                       2.286   Cond. No.                         20.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
#
# === qwen14 ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               prob_yes   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     19.52
# Date:                Tue, 05 May 2026   Prob (F-statistic):           1.78e-12
# Time:                        10:13:10   Log-Likelihood:                 42301.
# No. Observations:               42000   AIC:                        -8.459e+04
# Df Residuals:                   41996   BIC:                        -8.456e+04
# Df Model:                           3
# Covariance Type:              cluster
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  1.0146      0.002    490.136      0.000       1.011       1.019
# log_bystanders            -0.0151      0.002     -7.250      0.000      -0.019      -0.011
# urgency                   -0.0128      0.002     -5.804      0.000      -0.017      -0.008
# log_bystanders:urgency     0.0135      0.002      6.223      0.000       0.009       0.018
# ==============================================================================
# Omnibus:                    63594.637   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         17857714.692
# Skew:                          -9.810   Prob(JB):                         0.00
# Kurtosis:                     102.093   Cond. No.                         20.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)

# %%
rows = []

for model_name, res in results.items():
    for var, label in [
        ("log_bystanders", "Bystander effect"),
        ("log_bystanders:urgency", "Interaction effect")
    ]:
        coef = res.params[var]
        se = res.bse[var]

        rows.append({
            "model": model_name,
            "effect": label,
            "coef": coef,
            "ci_low": coef - 1.96 * se,
            "ci_high": coef + 1.96 * se
        })

coef_df = pd.DataFrame(rows)

# %%
coef_df["model"] = pd.Categorical(
    coef_df["model"], categories=model_order, ordered=True
)
coef_df = coef_df.sort_values("model")

# %%
df_b = coef_df[coef_df["effect"] == "Bystander effect"]

plt.figure(figsize=(3.2, 3.5*0.7))

plt.errorbar(
    df_b["coef"],
    df_b["model"],
    xerr=[
        df_b["coef"] - df_b["ci_low"],
        df_b["ci_high"] - df_b["coef"]
    ],
    fmt="o",
    capsize=3,
    color = "black",
    linewidth = 1.5,
    markersize = 3
)

plt.axvline(0, linestyle="--", c = "r")
plt.xlabel("Coefficient value", fontsize = 10, labelpad = 8)
plt.ylabel("Model", fontsize = 10, labelpad = 8)
plt.yticks(fontsize = 10)
plt.xticks(np.arange(-0.3, 0.15, 0.1), fontsize = 10)
plt.xlim(-0.35, 0.15)
#plt.title("Effect of bystanders on response probability")

plt.tight_layout()
plt.savefig("plots/yesno/bystander_coef.pdf")
plt.show()

# %%
df_i = coef_df[coef_df["effect"] == "Interaction effect"]

plt.figure(figsize=(3.2, 3.5*0.7))

plt.errorbar(
    df_i["coef"],
    df_i["model"],
    xerr=[
        df_i["coef"] - df_i["ci_low"],
        df_i["ci_high"] - df_i["coef"]
    ],
    fmt="o",
    capsize=3,
    color = "black",
    linewidth = 1.5,
    markersize = 3
)

plt.axvline(0, linestyle="--", c = "r")
plt.xlabel("Coefficient value", fontsize = 10, labelpad = 8)
plt.ylabel("*", fontsize = 10, labelpad = 8, c = "white")
plt.yticks(fontsize = 10)
plt.xticks(np.arange(-0.3, 0.15, 0.1), fontsize = 10)
plt.xlim(-0.35, 0.15)
#plt.title("Interaction")

plt.tight_layout()
plt.savefig("plots/yesno/interaction_coef.pdf")
plt.show()

# %% [markdown]
# ### Calculate Summary Scores

# %%
def calculate_area_under_curve(df_dict):
    """
    Calculate the area between the actual curve and a horizontal baseline
    set at the first column mean for each model.
    """
    area_scores = {}
    
    for model_name, df in df_dict.items():
        
        # Calculate average prob for each number of bystanders
        column_means = df.mean(axis=0)
        num_byst = column_means.index.astype(int)

        # Baseline: horizontal line at the first column mean
        baseline = column_means.iloc[0]
        baseline_curve = np.full_like(column_means, fill_value=baseline, dtype=float)

        # maximum curve would be starting at baseline, then going down to 0
        max_traj = [baseline] + [0] * (len(num_byst) -1)

        # Area between the actual curve and the baseline
        actual_area = np.trapezoid(column_means, num_byst)
        baseline_area = np.trapezoid(baseline_curve, num_byst)
        area_between = baseline_area - actual_area

        # area between the baseline and the maximum curve
        maximum_area = np.trapezoid(max_traj, num_byst)
        max_area_between = baseline_area - maximum_area

        # normalize actual area by maximum area
        normalized_area = area_between / max_area_between

        area_scores[model_name] = normalized_area

    return area_scores

# %%
scores_noturgent = calculate_area_under_curve(result_dfs)
scores_urgent = calculate_area_under_curve(result_dfs_urgent)

# %%
summary_scores = pd.DataFrame([scores_noturgent, scores_urgent], index = ["yesno_noturgent", "yesno_urgent"])

# %%
summary_scores.to_csv("results/summary_yesno.csv", index_label = "Experiment")
